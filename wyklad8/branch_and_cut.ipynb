# %% [markdown]
# # Branch and Cut
#
# "[**Revival of the Gomory cuts in the 1990's**](https://www.researchgate.net/publication/220462226_Revival_of_the_Gomory_cuts_in_the_1990's)", Gérard Cornuéjols

# %% [markdown]
# ![screenshot%20from%202021-05-12%2008-09-50.png](attachment:screenshot%20from%202021-05-12%2008-09-50.png)
# ![screenshot%20from%202021-05-12%2008-09-54.png](attachment:screenshot%20from%202021-05-12%2008-09-54.png)

# %%
# !pip install pydot scipy networkx matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import tsp

# %%
coords = tsp.Coords(5, seed=1)

# %%
coords.plot()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
P = coords.linear_problem()

# %%
show(P)
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)

# %%
coords.print_solution(P)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 4: 1.0
# 3 --> 2: 1.0
# 4 --> 3: 1.0
# BINARY MULTIPLE SUBTOURS 2.17713553231494

# %%
coords.plot_solution(P)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tsp.find_subtours(P)
# Out:
# [[0, 1], [2, 4, 3]]

# %%
P1 = tsp.remove_subtour(P, [0,1])

# %%
show(P1)
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)

# %%
coords.print_solution(P1)
# Out:
# 0 --> 1: 1.0
# 1 --> 3: 1.0
# 2 --> 0: 1.0
# 3 --> 4: 1.0
# 4 --> 2: 1.0
# BINARY FEASIBLE 2.7105523003205367

# %%
coords.plot_solution(P1)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
coords.print_solution(P1)
# Out:
# 0 --> 1: 1.0
# 1 --> 3: 1.0
# 2 --> 0: 1.0
# 3 --> 4: 1.0
# 4 --> 2: 1.0
# BINARY FEASIBLE 2.7105523003205367

# %%
P2 = tsp.remove_subtour(P, [2, 3, 4])

# %%
coords.print_solution(P2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 4: 1.0
# 3 --> 2: 1.0
# 4 --> 3: 1.0
# BINARY MULTIPLE SUBTOURS 2.17713553231494

# %%
show(P2)
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)

# %%
coords.plot_solution(P2)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
P3 = tsp.remove_subtour(P2, [3, 2, 4])

# %%
coords.print_solution(P3)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 0.33333333333333337
# 2 --> 4: 0.6666666666666666
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.3333333333333333
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666666
# FRACTIONAL 2.17713553231494

# %%
P4, P5 = tsp.branch_on(P3, 2, 3)

# %%
coords.print_solution(P4)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.6666666666666667
# 1 --> 3: 0.3333333333333333
# 2 --> 0: 0.33333333333333326
# 2 --> 4: 0.6666666666666667
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.33333333333333326
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666665
# FRACTIONAL 2.354941121650139

# %%
coords.print_solution(P5)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.5
# 1 --> 4: 0.5
# 2 --> 3: 1.0
# 3 --> 2: 0.5
# 3 --> 4: 0.5
# 4 --> 0: 0.5
# 4 --> 2: 0.5
# FRACTIONAL 2.7677177260971604

# %%
tree = tsp.Tree(coords)

# %%
tree.plot()

# %%
tree.solution(0)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(0)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 4: 1.0
# 3 --> 2: 1.0
# 4 --> 3: 1.0
# BINARY MULTIPLE SUBTOURS 2.17713553231494

# %%
tree.remove_subtour(0, [2, 3, 4])

# %%
tree.plot()

# %%
tree.print(1)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 0.33333333333333337
# 2 --> 4: 0.6666666666666666
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.3333333333333333
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666666
# FRACTIONAL 2.17713553231494

# %%
tree.branch_on(1, 23)

# %%
tree.plot()

# %%
tree.print(2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.6666666666666667
# 1 --> 3: 0.3333333333333333
# 2 --> 0: 0.33333333333333326
# 2 --> 4: 0.6666666666666667
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.33333333333333326
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666665
# FRACTIONAL 2.354941121650139

# %%
tree.print(3)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.5
# 1 --> 4: 0.5
# 2 --> 3: 1.0
# 3 --> 2: 0.5
# 3 --> 4: 0.5
# 4 --> 0: 0.5
# 4 --> 2: 0.5
# FRACTIONAL 2.7677177260971604

# %%
tree.branch_on(3, 10)

# %%
tree.plot()

# %%
tree.solution(4)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(5)
# Out:
# 0 --> 1: 0.5
# 0 --> 4: 0.5
# 1 --> 0: 1.0
# 2 --> 3: 1.0
# 3 --> 2: 0.5
# 3 --> 4: 0.5
# 4 --> 1: 0.5
# 4 --> 2: 0.5
# FRACTIONAL 2.7677177260971604

# %%
tree.branch_on(5, 01)

# %%
tree.plot()

# %%
tree.solution(6)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.6666666666666667
# 1 --> 3: 0.3333333333333333
# 2 --> 0: 0.33333333333333326
# 2 --> 4: 0.6666666666666667
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.33333333333333326
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666665
# FRACTIONAL 2.354941121650139

# %%
tree.branch_on(2, 10)

# %%
tree.plot()

# %%
tree.solution(8)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(9)
# Out:
# 0 --> 1: 0.6666666666666667
# 0 --> 3: 0.3333333333333333
# 1 --> 0: 1.0
# 2 --> 1: 0.33333333333333326
# 2 --> 4: 0.6666666666666667
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.33333333333333326
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666665
# FRACTIONAL 2.440692192744543

# %%
tree.branch_on(9, 01)

# %%
tree.plot()

# %%
tree.solution(10)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree = tsp.Tree(coords)

# %%
tree.plot()

# %%
tree.remove_subtour(0, [2,3,4])

# %%
tree.plot()

# %%
tree.print(1)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 0.33333333333333337
# 2 --> 4: 0.6666666666666666
# 3 --> 2: 0.6666666666666667
# 3 --> 4: 0.3333333333333333
# 4 --> 2: 0.33333333333333326
# 4 --> 3: 0.6666666666666666
# FRACTIONAL 2.17713553231494

# %%
tree.gomory_cut(1)
# Out:
# Cutting on x_23 value 0.33333333333333337 (y21, x_32, y23, x_43, y25, x_12, y27, x_10, y29, x_01, x_40, x_24, x_30, x_23, x_34, y36, y37, y38, y39, y40, y41, y42, y43, y44, y45, y46, y47, y48, y49, y50, y51, y52, y53, y54, y55, y56, y33)

# %%
tree.plot()

# %%
tree.print(2)
# Out:
# 0 --> 1: 1.0
# 0 --> 3: -4.1633363423443364e-17
# 1 --> 0: 0.5000000000000001
# 1 --> 3: 0.5
# 2 --> 0: 0.4999999999999999
# 2 --> 3: 0.33333333333333337
# 2 --> 4: 0.16666666666666674
# 3 --> 2: 0.16666666666666666
# 3 --> 4: 0.8333333333333333
# 4 --> 2: 0.8333333333333334
# 4 --> 3: 0.16666666666666663
# FRACTIONAL 2.4438439163177383

# %%
tree.branch_on(2, 10)

# %%
tree.plot()

# %%
tree.solution(3)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(4)
# Out:
# 0 --> 1: 0.5000000000000002
# 0 --> 3: 0.49999999999999967
# 1 --> 0: 1.0
# 2 --> 3: 0.5000000000000001
# 2 --> 4: 0.4999999999999999
# 3 --> 1: 0.49999999999999994
# 3 --> 2: -2.2204460492503128e-16
# 3 --> 4: 0.5000000000000001
# 4 --> 2: 0.9999999999999998
# 4 --> 3: 2.220446049250313e-16
# FRACTIONAL 2.500691262480888

# %%
tree.branch_on(4, 01)

# %%
tree.plot()

# %%
tree.solution(5)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.remove_subtour(5, [2,4])

# %%
tree.plot()

# %%
tree.print(7)
# Out:
# 0 --> 2: 0.33333333333333326
# 0 --> 3: 0.6666666666666667
# 1 --> 0: 1.0
# 2 --> 1: 0.6666666666666666
# 2 --> 4: 0.33333333333333337
# 3 --> 1: 0.3333333333333335
# 3 --> 4: 0.6666666666666666
# 4 --> 2: 0.6666666666666667
# 4 --> 3: 0.33333333333333326
# FRACTIONAL 2.8820544425093453

# %%
tree.branch_on(7, 02)

# %%
tree.plot()

# %%
tree.print(8)
# Out:
# 0 --> 3: 1.0
# 0 --> 4: -7.401486830834377e-17
# 1 --> 0: 1.0
# 2 --> 1: 1.0
# 3 --> 2: -7.401486830834377e-17
# 3 --> 4: 1.0
# 4 --> 2: 1.0
# FRACTIONAL 2.9678055136037482
