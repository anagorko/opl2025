# %% [markdown]
# # Cięcia Gomory'ego

# %% [markdown]
# "**[The Ongoing Story of Gomory Cuts](https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.399.656&rep=rep1&type=pdf)**", Gerard Cornu
#
# > The story of Gomory cuts is characterized by swings between great acclaim in
# the early days, near oblivion for decades and an amazing comeback in the last
# 20 years. These cuts have been described as “elegant”, “disappointing” and
# “the clear winner” at various times over the last 55 years. This essay retraces
# that roller coaster. Ralph Gomory’s paper “Early Integer Programming” recounts
# his discovery of fractional cuts. It is a few years after he wrote his doctoral dissertation on
# nonlinear differential equations that he heard of linear programming for the
# first time.  He was working for the Navy at the time.  In one particular instance,
# it would have been preferable to have solutions in integers. Gomory
# thought that, somehow, one should be able to accomplish this. Within a few
# days he had invented fractional cuts. His approach was to first solve the linear
# program and then, using appropriate integer linear forms, to generate valid
# linear inequalities cutting off the undesirable fractional
# solution. By adding these cuts to the linear program, solving again using the simplex algorithm
# and iterating, Gomory could solve by hand any small integer linear program
# that he tried. However, he did not have a finiteness proof yet. At this point, he happened to run into Martin Beale in the halls of Princeton
# University in late 1957 and mentioned that he could solve linear programs in integers. When
# Beale immediately responded “but that’s impossible”, Gomory realized that he was not the first to think about this problem.
# As it turns out, Dantzig, Fulkerson, and Johnson had pioneered the cutting plane approach in a seminal paper published in 1954.
# They devised special-purpose cuts for the traveling salesman problem and, as a result, were able to solve to optimality an instance
# with 48 cities. However, Gomory’s goal was different and more ambitious. His fractional cuts were general-purpose cuts that applied to all integer linear programs.
#
# > (...)
#
# > When Gomory presented his results in early 1958, the impact was enormous and immediate. Gomory had achieved the impossible: reducing integer linear
# programming to a sequence of linear programs. This was a great theoretical breakthrough.

# %% [markdown]
# ## Cięcia
#
# Dany jest problem z nieliniowymi warunkami (w naszym przypadku warunkami całkowitoliczbowości: $x \in \mathbb{Z}^n$)
#
# Jeżeli $x^\ast$ jest rozwiązaniem optymalnym relaksacji problemu całkowitoliczbowego, naruszającym któryś z warunków całkowitoliczbowości, to dowolną nierówność, która
#   nie jest spełniona przez $x^\ast$ a jest spełniona

# %% [markdown]
# ## Cięcia Gomory'ego
#
# Dany jest problem optymalizacyjny
#
# $c^T x \to \max \\
# Ax \leq b, \\
# x \geq 0 \\
# x \in \mathbb{Z}^n$
#
# liniowy z dodatkowymi **nieliniowymi** warunkami $x \in \mathbb{Z}^n$. Uwaga: zakładamy, że **wszystkie** zmienne mają przyjąć wartości całkowite i wszystkie współczynniki problemu są całkowite ($A \in M_{m\times n}(\mathbb{Z})$, $b \in \mathbb{Z}^m$, $c \in \mathbb{Z}^n$). Za pomocą metody sympleks rozwiązujemy **relaksację** problemu
#
# $
# c^T x \to \max \\
# Ax \leq b, \\
# x \geq 0
# $
#
# znajdując zbiór bazowy optymalny $\mathcal{B}$ i rozwiązanie bazowe optymalne $x^\ast \in \mathbb{R}^n$ takie, że
#
# $
# x^\ast_\mathcal{B} = A^{-1}_\mathcal{B} b\\
# x^\ast_\mathcal{N} = 0.
# $
#
# Znamy też wartość funkcji celu:
#
# $
# \xi = \xi^\ast - (c^\ast)^T x_\mathcal{N}.
# $
#
# (Dla pewnych wartości $\xi^\ast$, $c^\ast$ których tu nie specyfikujemy.)

# %% [markdown]
# Jeżeli $x^\ast \in \mathbb{Z}^n$, to rozwiązaliśmy dany problem. W przeciwnym przypadku wybieramy indeks $i \in \mathcal{B}$ taki, że $x^\ast_i \not\in \mathbb{Z}$.
# W tabelce mamy wiersz
#
# $
# x_i = b^\ast_i - \sum_{j \in \mathcal{N}} a^\ast_{ij} x_j.
# $
#
# Oczywiście $b^\ast_i$ nie jest całkowite. Jeżeli wszystkie współczynniki $a^\ast_{ij}$ są nieujemne, to oczywiście każde rozwiązanie problemu spełnia nierówność
#
# $
# x_i \leq b^\ast_i
# $
#
# a każde całkowitoliczbowe rozwiązanie spełnia nierówność
#
# $
# x_i \leq \lfloor b^\ast_i \rfloor.
# $
#
# Jest to cięcie - ta nie równość nie odcina żadnych rozwiązań całkowitoliczbowych problemu, a odcina rozwiązanie $x^\ast$. Oczywiście zazwyczaj niektóre współczynniki $a^\ast_{ij}$ będą ujemne. Wtedy możemy przepisać nasze równanie:
#
# $
# x_i = b^\ast_i - \sum_{j \in \mathcal{N}} a^\ast_{ij} x_j = b^\ast_i - \sum_{j \in \mathcal{N}} (\lfloor a^\ast_{ij} \rfloor + \{ a^\ast_{ij} \}) x_j
# $
#
# gdzie $\{ x \}$ to taka liczba, że $x = \lfloor x \rfloor + \{ x \}$. Oczywiście $\{ x \} \geq 0$ dla każdego $x \in \mathbb{R}$. Wtedy
#
# $
# x_i \leq \lfloor b^\ast_i \rfloor - \sum_{j \in \mathbb{N}} \lfloor a^\ast_{ij} \rfloor x_j
# $
#
# Tę nierówność nazywamy **cięciem Gomory'ego**. Uwaga: jeżeli pojawiają się tu zmienne dodane przy przejściu do postaci równościowej, to zastępujemy je zmiennymi oryginalnego problemu używając podstawień z oryginalnej tabelki.
#
# Cięcie jest poprawne, bo
#
# $
# x_i + \sum_{j \in \mathcal{N}} \lfloor a^\ast_{ij} \rfloor x_j = b^\ast_i - \sum_{j \in \mathbb{N}} \lfloor a^\ast_{ij} \rfloor x_j \leq b^\ast_i
# $
#
# i lewa strona nierówności musi przyjmować wartość całkowitą dla $x \in \mathbb{Z}^n$ (tu pokazuje się konieczność założenia, że wszystkie zmienne $x_i$ mają być całkowite, w tym zmienne dodane - do tego potrzebna jest całkowitoliczbowość $A$ i $b$).
#
# Skoro $c \in \mathbb{Z}^n$, to analogicznie możemy utworzyć cięcie z równości
#
# $
# \xi = \xi^\ast - (c^\ast)^T x_\mathcal{N},
# $
#
# bo wiemy, że wartość $\xi$ musi być całkowita.
# Tu akurat (skoro $x^\ast$ było rozwiązaniem optymalnym) cięciem będzie po prostu
#
# $
# \xi \leq \lfloor \xi^\ast \rfloor.
# $

# %% [markdown]
# ## Przykład

# %%
A = matrix(QQ, 2, 2, [3, -1, 3, 11])
b = matrix(QQ, 2, 1, [12, 66])
c = matrix(QQ, 1, 2, [3, 4])

P = InteractiveLPProblemStandardForm(A,b,c)
show(P)
show(plot(P, xmin=0, xmax=7, ymin=0, ymax=7))
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)
# Graphics object consisting of 17 graphics primitives

# %%
P.run_simplex_method()
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# \color{red}{x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 12 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 66 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{1}$. Leaving: $x_{3}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{1}{3} x_{2}}\\
# \color{red}{x_{4} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 54 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 12 x_{2}}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 12 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{2}$. Leaving: $x_{4}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{11}{2} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{11}{36} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{36} x_{4}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{9}{2} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{12} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{12} x_{4}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{69}{2} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{7}{12} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{5}{12} x_{4}\\
# \hline
# \end{array}
# \end{equation*}
# The optimal value: $\frac{69}{2}$. An optimal solution: $\left(\frac{11}{2},\,\frac{9}{2}\right)$.

# %%
# ... generujemy cięcia dla wszystkich trzech równości ...

P1 = P.add_constraint([1, 0], 5)
P1 = P1.add_constraint([3, 4], 34)
show(P1)
show(plot(P1, xmin=0, xmax=7, ymin=0, ymax=7))
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)
# Graphics object consisting of 21 graphics primitives

# %%
show(P1.run_simplex_method())
show(P1.initial_dictionary())
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# \color{red}{x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 12 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 66 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} \\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 34 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{1}$. Leaving: $x_{3}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{1}{3} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 54 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 12 x_{2}}\\
# \color{red}{x_{5} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} \frac{1}{3} x_{2}}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 22 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 12 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{2}$. Leaving: $x_{5}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\color{green}{\mspace{-6mu}  \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{5}\\
# \color{red}{x_{4} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 18 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 11 x_{3} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 36 x_{5}}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3 x_{5}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 27 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{3}$. Leaving: $x_{4}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{5}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{18}{11} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{11} x_{4} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{36}{11} x_{5}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{51}{11} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{11} x_{4} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{3}{11} x_{5}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{5}{11} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{4}{11} x_{4} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{21}{11} x_{5}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{369}{11} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{4}{11} x_{4} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{21}{11} x_{5}\\
# \hline
# \end{array}
# \end{equation*}
# The optimal value: $\frac{369}{11}$. An optimal solution: $\left(5,\,\frac{51}{11}\right)$.
# LP problem dictionary (use 'view(...)' or '%display typeset' for details)

# %%
# x2 = 51/11- ... x4 + x5 - ... x5
# x2 - x5 <= 51/11
# x2 - x5 <= 4
# x2 - 5 + x1 <= 4
# x1 + x2 <= 9

P2 = P1.add_constraint([1, 1], 9)
show(P2)
show(plot(P2, xmin=0, xmax=7, ymin=0, ymax=7))
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)
# Graphics object consisting of 23 graphics primitives

# %%
show(P2.run_simplex_method())
show(P2.initial_dictionary())
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# \color{red}{x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 12 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 66 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} \\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 34 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# x_{7} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 9 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{1}$. Leaving: $x_{3}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{1}{3} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 54 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 12 x_{2}}\\
# \color{red}{x_{5} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} \frac{1}{3} x_{2}}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 22 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# x_{7} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{4}{3} x_{2}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 12 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{2}$. Leaving: $x_{5}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\color{green}{\mspace{-6mu}  \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{5}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 18 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 11 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 36 x_{5}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3 x_{5}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \color{red}{x_{7} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} x_{3} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 4 x_{5}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 27 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{3}$. Leaving: $x_{7}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# \color{red}{x_{4} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 7 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 11 x_{7} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 8 x_{5}}}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{5}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 31 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{5}$. Leaving: $x_{4}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{33}{8} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{11}{8} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{8} x_{4}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{7}{8} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{11}{8} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{8} x_{4}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{39}{8} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{3}{8} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{8} x_{4}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{17}{8} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{21}{8} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{8} x_{4}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{9}{2} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{9}{2} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{2} x_{4}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{255}{8} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{21}{8} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{8} x_{4}\\
# \hline
# \end{array}
# \end{equation*}
# The optimal value: $\frac{255}{8}$. An optimal solution: $\left(\frac{33}{8},\,\frac{39}{8}\right)$.
# LP problem dictionary (use 'view(...)' or '%display typeset' for details)

# %%
# x1 - x4 <= 4
# x1 - 66 + 3x1 + 11x2 <= 4
# 4x1 + 11x2 <= 70

P3 = P2.add_constraint([4, 11], 70)
show(P3)
show(plot(P3, xmin=0, xmax=7, ymin=0, ymax=7))
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)
# Graphics object consisting of 25 graphics primitives

# %%
show(P3.run_simplex_method())
show(P3.initial_dictionary())
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# \color{red}{x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 12 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 66 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} \\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 34 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# x_{7} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 9 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{2}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 70 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{1}$. Leaving: $x_{3}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{1}{3} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 54 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 12 x_{2}}\\
# \color{red}{x_{5} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} \frac{1}{3} x_{2}}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 22 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# x_{7} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{4}{3} x_{2}}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 54 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{4}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{37}{3} x_{2}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 12 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{2}$. Leaving: $x_{5}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\color{green}{\mspace{-6mu}  \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{5}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 18 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 11 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 36 x_{5}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3 x_{5}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \color{red}{x_{7} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} x_{3} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 4 x_{5}}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 17 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 11 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 37 x_{5}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 27 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{3}$. Leaving: $x_{7}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 11 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 8 x_{5}}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{5}}\\
# \color{red}{x_{8} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 6 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 11 x_{7} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 7 x_{5}}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 31 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{5}$. Leaving: $x_{8}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{29}{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{11}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{7} x_{8}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{1}{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{11}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{8}{7} x_{8}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{34}{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{4}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{7} x_{8}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{15}{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{17}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{7} x_{8}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{31}{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{37}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{4}{7} x_{8}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{6}{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{11}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{7} x_{8}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} \frac{223}{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{17}{7} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{7} x_{8}\\
# \hline
# \end{array}
# \end{equation*}
# The optimal value: $\frac{223}{7}$. An optimal solution: $\left(\frac{29}{7},\,\frac{34}{7}\right)$.
# LP problem dictionary (use 'view(...)' or '%display typeset' for details)

# %%
# x2 - x7 <= 4
# x2 - 9 + x1 + x2 <= 4
# x1 + 2x2 <= 13

P4 = P3.add_constraint([1, 2], 13)
show(P4)
show(plot(P4, xmin=0, xmax=7, ymin=0, ymax=7))
# Out:
# LP problem (use 'view(...)' or '%display typeset' for details)
# Graphics object consisting of 27 graphics primitives

# %%
show(P4.run_simplex_method())
show(P4.initial_dictionary())
# Out:
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# \color{red}{x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 12 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 66 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} \\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 34 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# x_{7} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 9 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{2}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 70 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 11 x_{2}\\
# x_{9} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 13 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{1} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 2 x_{2}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 3 x_{1} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{2}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{1}$. Leaving: $x_{3}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{1}{3} x_{2}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 54 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 12 x_{2}}\\
# \color{red}{x_{5} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} \frac{1}{3} x_{2}}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 22 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# x_{7} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{4}{3} x_{2}}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 54 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{4}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{37}{3} x_{2}}\\
# x_{9} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 9 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} \frac{1}{3} x_{3} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} \frac{7}{3} x_{2}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 12 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{3} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 5 x_{2}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{2}$. Leaving: $x_{5}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\color{green}{\mspace{-6mu}  \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{5}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 18 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 11 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 36 x_{5}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3 x_{5}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \color{red}{x_{7} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 1 \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} x_{3} \mspace{-6mu}}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 4 x_{5}}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 17 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 11 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 37 x_{5}\\
# x_{9} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 2 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 2 x_{3} \mspace{-6mu}}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 7 x_{5}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 27 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{3} \mspace{-6mu}}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 15 x_{5}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{3}$. Leaving: $x_{7}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu}  \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 11 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 8 x_{5}}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 4 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} 4 x_{5}}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 6 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 11 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\color{green}{\mspace{-6mu} 7 x_{5}}\\
# \color{red}{x_{9} \mspace{-6mu}}&\color{red}{\mspace{-6mu} = \mspace{-6mu}}&\color{red}{\mspace{-6mu} 0 \mspace{-6mu}}&\color{red}{\mspace{-6mu} + \mspace{-6mu}}&\color{red}{\mspace{-6mu} 2 x_{7} \mspace{-6mu}}&\color{red}{\mspace{-6mu} - \mspace{-6mu}}&\color{blue}{{\mspace{-6mu} x_{5}}}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 31 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\color{green}{\mspace{-6mu} x_{5}}\\
# \hline
# \end{array}
# \end{equation*}
# Entering: $x_{5}$. Leaving: $x_{9}$.
# \begin{equation*}
# \renewcommand{\arraystretch}{1.5} %notruncate
# \begin{array}{|rcrcrcr|}
# \hline
# x_{1} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 5 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 2 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{9}\\
# x_{4} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 7 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 5 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 8 x_{9}\\
# x_{2} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 4 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{9}\\
# x_{6} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 3 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 2 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} x_{9}\\
# x_{3} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 1 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 7 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 4 x_{9}\\
# x_{8} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 6 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 3 x_{7} \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 7 x_{9}\\
# x_{5} \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 0 \mspace{-6mu}&\mspace{-6mu} + \mspace{-6mu}&\mspace{-6mu} 2 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{9}\\
# \hline
# z \mspace{-6mu}&\mspace{-6mu} = \mspace{-6mu}&\mspace{-6mu} 31 \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} 2 x_{7} \mspace{-6mu}&\mspace{-6mu} - \mspace{-6mu}&\mspace{-6mu} x_{9}\\
# \hline
# \end{array}
# \end{equation*}
# The optimal value: $31$. An optimal solution: $\left(5,\,4\right)$.
# LP problem dictionary (use 'view(...)' or '%display typeset' for details)
